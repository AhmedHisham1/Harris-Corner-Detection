# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2
import matplotlib.image as mpimg
from utils import harris_corner

# %matplotlib inline

# %%
img = mpimg.imread('images/waffle.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(gray, cmap='gray')

# %%
dst = harris_corner(gray, k=0.04)
# dst = cv2.dilate(dst, None)
plt.imshow(dst, cmap='gray')
dst.max()
corner_img = np.copy(img)
corner_img[dst>0.01*dst.max()]=[0,255,0]
plt.imshow(corner_img)

# %%
img = mpimg.imread('images/chess.jpg')
img = cv2.resize(img, (300,300), interpolation=cv2.INTER_AREA)
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

plt.imshow(img)

# %%
dst = harris_corner(gray, k=0.04)
# dst = cv2.dilate(dst, None)
plt.imshow(dst, cmap='gray')
dst.max()
corner_img = np.copy(img)
corner_img[dst>0.01*dst.max()]=[0,255,0]
plt.imshow(corner_img)
